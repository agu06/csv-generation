# %% [markdown]
# <a href="https://colab.research.google.com/github/agu06/csv-generation/blob/main/Generate_csv_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I'll extract the data from the image into a list of dictionaries and then convert it to a CSV file.

# %%
import pandas as pd

# Extract the data
data = [
    {
        "question": "Which of these letters is not part of the Yoruba alphabet?",
        "option_1": "Ẹ",
        "option_2": "F",
        "option_3": "Q",
        "option_4": "Ṣ",
        "correct_option": "c"
    },
    {
        "question": "What is the correct pronunciation of the Yoruba vowel 'ọ'?",
        "option_1": "/e/",
        "option_2": "/o/",
        "option_3": "/ɔ/",
        "option_4": "/a/",
        "correct_option": "c"
    },
    {
        "question": "What is the Yoruba word for 'ten'?",
        "option_1": "Ẹdẹgbẹta",
        "option_2": "Ọgọrun",
        "option_3": "Ẹwà",
        "option_4": "Mẹwàá",
        "correct_option": "d"
    },
    {
        "question": "How do you say 'three' in Yoruba?",
        "option_1": "Mẹjọ",
        "option_2": "Mẹta",
        "option_3": "Mẹẹta",
        "option_4": "Mẹẹjọ",
        "correct_option": "b"
    },
    {
        "question": "What is 'fish' in Yoruba?",
        "option_1": "Ẹja",
        "option_2": "Eṣin",
        "option_3": "Ẹran",
        "option_4": "Adìẹ",
        "correct_option": "a"
    },
    {
        "question": "How do you say 'house' in Yoruba?",
        "option_1": "Ilé",
        "option_2": "Ọkọ",
        "option_3": "Ọjà",
        "option_4": "Ọrẹ",
        "correct_option": "a"
    }
]

# Add `subject` key to each dictionary
for row in data:
    row['subject'] = 'Yoruba'

# Create a DataFrame from the extracted data
df = pd.DataFrame(data)

# Display the data
print(df.head().to_markdown(index=False, numalign="left", stralign="left"))

print(df.info())

# %% [markdown]
# ```text?code_stdout&code_event_index=3
# | question                                                   | option_1   | option_2   | option_3   | option_4   | correct_option   | subject   |
# |:-----------------------------------------------------------|:-----------|:-----------|:-----------|:-----------|:-----------------|:----------|
# | Which of these letters is not part of the Yoruba alphabet? | Ẹ          | F          | Q          | Ṣ          | c                | Yoruba    |
# | What is the correct pronunciation of the Yoruba vowel 'ọ'? | /e/        | /o/        | /ɔ/        | /a/        | c                | Yoruba    |
# | What is the Yoruba word for 'ten'?                         | Ẹdẹgbẹta   | Ọgọrun     | Ẹwà        | Mẹwàá      | d                | Yoruba    |
# | How do you say 'three' in Yoruba?                          | Mẹjọ       | Mẹta       | Mẹẹta      | Mẹẹjọ      | b                | Yoruba    |
# | What is 'fish' in Yoruba?                                  | Ẹja        | Eṣin       | Ẹran       | Adìẹ       | a                | Yoruba    |
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   question        6 non-null      object
#  1   option_1        6 non-null      object
#  2   option_2        6 non-null      object
#  3   option_3        6 non-null      object
#  4   option_4        6 non-null      object
#  5   correct_option  6 non-null      object
#  6   subject         6 non-null      object
# dtypes: object(7)
# memory usage: 464.0+ bytes
# None
#
# ```
# I'll now create a CSV file with the extracted data.

# %%
# Save the data
df.to_csv('yoruba_questions.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7f70ef10786> in <cell line: 2>()
#       1 # Save the data
# ----> 2 df.to_csv('yoruba_questions.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
import pandas as pd
from google.colab import files

# Step 1: Prepare the data
data = [
    {
        "subject": "Yoruba",
        "question": "Which of these letters is not part of the Yoruba alphabet?",
        "option_1": "Ẹ",
        "option_2": "F",
        "option_3": "Q",
        "option_4": "Ṣ",
        "correct_option": "Q"
    },
    {
        "subject": "Yoruba",
        "question": "What is the correct pronunciation of the Yoruba vowel 'ọ'?",
        "option_1": "/e/",
        "option_2": "/o/",
        "option_3": "/ɔ/",
        "option_4": "/a/",
        "correct_option": "/ɔ/"
    },
    {
        "subject": "Yoruba",
        "question": "What is the Yoruba word for 'ten'?",
        "option_1": "Ẹdẹgbẹta",
        "option_2": "Ọgọrun",
        "option_3": "Ẹwà",
        "option_4": "Mẹwàá",
        "correct_option": "Mẹwàá"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'three' in Yoruba?",
        "option_1": "Mẹjọ",
        "option_2": "Mẹta",
        "option_3": "Mẹẹta",
        "option_4": "Mẹẹjọ",
        "correct_option": "Mẹta"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'fish' in Yoruba?",
        "option_1": "Ẹja",
        "option_2": "Eṣin",
        "option_3": "Ẹran",
        "option_4": "Adìẹ",
        "correct_option": "Ẹja"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'house' in Yoruba?",
        "option_1": "Ilé",
        "option_2": "Ọkọ",
        "option_3": "Ọjà",
        "option_4": "Ọrẹ",
        "correct_option": "Ilé"
    },
    {
        "subject": "Yoruba",
        "question": "What does 'emi' mean?",
        "option_1": "You (singular)",
        "option_2": "They",
        "option_3": "I",
        "option_4": "We",
        "correct_option": "I"
    },
    {
        "subject": "Yoruba",
        "question": "Which of these is the Yoruba word for 'we'?",
        "option_1": "Ọwọ",
        "option_2": "Awa",
        "option_3": "Wọn",
        "option_4": "Ẹyin",
        "correct_option": "Awa"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'eye' in Yoruba?",
        "option_1": "Ọwọ",
        "option_2": "Ẹsẹ",
        "option_3": "Ojú",
        "option_4": "Ẹnu",
        "correct_option": "Ojú"
    },
    {
        "subject": "Yoruba",
        "question": "Translate 'mouth' into Yoruba.",
        "option_1": "Ẹsẹ",
        "option_2": "Ẹnu",
        "option_3": "Ojú",
        "option_4": "Ọgbọn",
        "correct_option": "Ẹnu"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'right' in Yoruba?",
        "option_1": "Ọtun",
        "option_2": "Ọsẹ",
        "option_3": "Osi",
        "option_4": "Ẹyin",
        "correct_option": "Ọtun"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'Where is the school?' in Yoruba?",
        "option_1": "Nibo ni ile-iwe wa?",
        "option_2": "Nibo ni ọjà wa?",
        "option_3": "Nibo ni ile wa?",
        "option_4": "Nibo ni ọkọ wa?",
        "correct_option": "Nibo ni ile-iwe wa?"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'mother' in Yoruba?",
        "option_1": "Baba",
        "option_2": "Aburo",
        "option_3": "Iya",
        "option_4": "Egbon",
        "correct_option": "Iya"
    },
    {
        "subject": "Yoruba",
        "question": "Translate 'brother' into Yoruba.",
        "option_1": "Egbon",
        "option_2": "Aburo",
        "option_3": "Ọrẹ",
        "option_4": "Baba",
        "correct_option": "Egbon"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'yam' in Yoruba?",
        "option_1": "Iresi",
        "option_2": "Agbado",
        "option_3": "Ẹlẹdẹ",
        "option_4": "Isu",
        "correct_option": "Isu"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'rice' in Yoruba?",
        "option_1": "Iresi",
        "option_2": "Ẹja",
        "option_3": "Ewa",
        "option_4": "Ọka",
        "correct_option": "Iresi"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'blue' in Yoruba?",
        "option_1": "Funfun",
        "option_2": "Dudu",
        "option_3": "Búlúù",
        "option_4": "Pupa",
        "correct_option": "Búlúù"
    },
    {
        "subject": "Yoruba",
        "question": "What is 'white' in Yoruba?",
        "option_1": "Pupa",
        "option_2": "Funfun",
        "option_3": "Dudu",
        "option_4": "Alawọ",
        "correct_option": "Funfun"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'chicken' in Yoruba?",
        "option_1": "Adìẹ",
        "option_2": "Ẹran",
        "option_3": "Ẹṣin",
        "option_4": "Ẹja",
        "correct_option": "Adìẹ"
    },
    {
        "subject": "Yoruba",
        "question": "What is the Yoruba word for 'horse'?",
        "option_1": "Ẹṣin",
        "option_2": "Ẹran",
        "option_3": "Adìẹ",
        "option_4": "Ẹja",
        "correct_option": "Ẹṣin"
    },
    {
        "subject": "Yoruba",
        "question": "What is the Yoruba word for 'happy'?",
        "option_1": "Inu mi dun",
        "option_2": "Inu mi nja",
        "option_3": "Ẹru ba mi",
        "option_4": "Ibanujẹ wa mi",
        "correct_option": "Inu mi dun"
    },
    {
        "subject": "Yoruba",
        "question": "Translate 'angry' to Yoruba.",
        "option_1": "Inu mi nrun",
        "option_2": "Inu mi dun",
        "option_3": "Ibanujẹ wa mi",
        "option_4": "Inu mi fẹ",
        "correct_option": "Inu mi nrun"
    },
    {
        "subject": "Yoruba",
        "question": "What is the Yoruba verb for 'to go'?",
        "option_1": "Lọ",
        "option_2": "Wa",
        "option_3": "Jẹ",
        "option_4": "Sun",
        "correct_option": "Lọ"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'to eat' in Yoruba?",
        "option_1": "Sun",
        "option_2": "Jẹ",
        "option_3": "Rìn",
        "option_4": "Lọ",
        "correct_option": "Jẹ"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'Good evening' in Yoruba?",
        "option_1": "E ku iṣẹ",
        "option_2": "E kaalẹ",
        "option_3": "E ku owurọ",
        "option_4": "Ẹ se",
        "correct_option": "E kaalẹ"
    },
    {
        "subject": "Yoruba",
        "question": "Translate 'Thank you' into Yoruba.",
        "option_1": "Ẹ ku oriire",
        "option_2": "Ẹ se",
        "option_3": "Ẹ ku iṣẹ",
        "option_4": "Ẹ ku ikọkọ",
        "correct_option": "Ẹ se"
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'My name is Ade' in Yoruba?",
        "option_1": "Orukọ mi ni Ade",
        "option_2": "Ẹ jẹ ki n sọ pe Ade ni mi",
        "option_3": "Ọmọ mi ni Ade",
        "option_4": "Ile mi wa ni Ade",
        "correct_option": "Orukọ mi ni Ade"
    },
    {
        "subject": "Yoruba",
        "question": "What is the Yoruba equivalent of 'Where do you live?'",
        "option_1": "Nibo ni o gbe?",
        "option_2": "Nibo ni o nlo?",
        "option_3": "Ẹ fẹ lati gbe nibo?",
        "option_4": "Nibo ni o n sun?",
        "correct_option": "Nibo ni o gbe?"
    },
    {
        "subject": "Yoruba",
        "question": "Which of these is a Yoruba proverb?",
        "option_1": "\"Ẹni tí ńṣòwò kò gbọ́n ju ọkọ lọ\"",
        "option_2": "\"Otu onye anaghị atụ mmiri\"",
        "option_3": "\"Ẹni tí ó ṣẹ òhun ńjẹ nǹkan tó mọ́.\"",
        "option_4": "\"Ṣe daada, a máa ṣe dáada sí ọ\"",
        "correct_option": "\"Ẹni tí ó ṣẹ òhun ńjẹ nǹkan tó mọ́.\""
    },
    {
        "subject": "Yoruba",
        "question": "How do you say 'festival' in Yoruba?",
        "option_1": "Ajọdun",
        "option_2": "Orin",
        "option_3": "Ẹja",
        "option_4": "Aṣọ",
        "correct_option": "Ajọdun"
    }
]

df = pd.DataFrame(data)
df.to_csv("yoruba_questions.csv", index=False)

files.download('yoruba_questions.csv')

# %% [markdown]
# [file-tag: code-generated-file-8-0-1736944720204332966]
#
# I've created the CSV file with the information you provided.
